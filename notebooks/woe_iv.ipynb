# %%
from sklearn.datasets import load_breast_cancer
from mightypy.stats import woe_and_iv

dataset = load_breast_cancer(as_frame=True)
df = dataset.frame[['mean radius', 'target']]

target_map = {
    0: 'False',
    1: 'True'
}

df['label'] = df['target'].map(target_map)

# print(df)
cal_df, iv = woe_and_iv(df, event='True', non_event='False', target_col='label',
                        bucket_col='mean radius')
# Out:
# <ipython-input-1-2221c1bac0a5>:12: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['label'] = df['target'].map(target_map)

# %%
cal_df
# Out:
# label                        False  True  adj_event  adj_non_event  \
# buckets_mean radius
# (6.9799999999999995, 10.26]    0.0  58.0       58.5            0.5
# (10.26, 11.366]                2.0  54.0       54.0            2.0
# (11.366, 12.012]               4.0  53.0       53.0            4.0
# (12.012, 12.726]               4.0  53.0       53.0            4.0
# (12.726, 13.37]                7.0  50.0       50.0            7.0
# (13.37, 14.058]               15.0  41.0       41.0           15.0
# (14.058, 15.056]              20.0  37.0       37.0           20.0
# (15.056, 17.068]              47.0  10.0       10.0           47.0
# (17.068, 19.53]               57.0   1.0        1.0           57.0
# (19.53, 28.11]                56.0   0.0        0.5           56.5
#
# label                        %_event_True  %_non_event_False       woe  \
# buckets_mean radius
# (6.9799999999999995, 10.26]      0.163866           0.002358 -4.241024
# (10.26, 11.366]                  0.151261           0.009434 -2.774687
# (11.366, 12.012]                 0.148459           0.018868 -2.062848
# (12.012, 12.726]                 0.148459           0.018868 -2.062848
# (12.726, 13.37]                  0.140056           0.033019 -1.444963
# (13.37, 14.058]                  0.114846           0.070755 -0.484372
# (14.058, 15.056]                 0.103641           0.094340 -0.094036
# (15.056, 17.068]                 0.028011           0.221698  2.068712
# (17.068, 19.53]                  0.002801           0.268868  4.564201
# (19.53, 28.11]                   0.001401           0.266509  5.248537
#
# label                              iv
# buckets_mean radius
# (6.9799999999999995, 10.26]  0.684955
# (10.26, 11.366]              0.393524
# (11.366, 12.012]             0.267327
# (12.012, 12.726]             0.267327
# (12.726, 13.37]              0.154665
# (13.37, 14.058]              0.021357
# (14.058, 15.056]             0.000875
# (15.056, 17.068]             0.400682
# (17.068, 19.53]              1.214382
# (19.53, 28.11]               1.391434

# %%
cal_df
# Out:
# label                        False  True  percentage_event_True  \
# buckets_mean radius
# (6.9799999999999995, 10.26]    0.0  58.0               0.162465
# (10.26, 11.366]                2.0  54.0               0.151261
# (11.366, 12.012]               4.0  53.0               0.148459
# (12.012, 12.726]               4.0  53.0               0.148459
# (12.726, 13.37]                7.0  50.0               0.140056
# (13.37, 14.058]               15.0  41.0               0.114846
# (14.058, 15.056]              20.0  37.0               0.103641
# (15.056, 17.068]              47.0  10.0               0.028011
# (17.068, 19.53]               57.0   1.0               0.002801
# (19.53, 28.11]                56.0   0.0               0.000000
#
# label                        percentage_non_event_False       woe        iv
# buckets_mean radius
# (6.9799999999999995, 10.26]                    0.000000      -inf       inf
# (10.26, 11.366]                                0.009434 -2.774687  0.393524
# (11.366, 12.012]                               0.018868 -2.062848  0.267327
# (12.012, 12.726]                               0.018868 -2.062848  0.267327
# (12.726, 13.37]                                0.033019 -1.444963  0.154665
# (13.37, 14.058]                                0.070755 -0.484372  0.021357
# (14.058, 15.056]                               0.094340 -0.094036  0.000875
# (15.056, 17.068]                               0.221698  2.068712  0.400682
# (17.068, 19.53]                                0.268868  4.564201  1.214382
# (19.53, 28.11]                                 0.264151       inf       inf
